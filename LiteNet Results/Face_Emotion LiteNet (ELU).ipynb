# %%
from __future__ import print_function
import keras
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten, BatchNormalization
from keras.layers import Conv2D, MaxPooling2D
from keras.preprocessing.image import ImageDataGenerator
import os

num_classes = 4
img_rows, img_cols = 48, 48
input_shape = (img_rows, img_cols,1)
batch_size = 64

train_data_dir = 'C:\\Users\\Admin\\Desktop\\Research\\Datasets Used\\Face_Emotion\\train'
validation_data_dir = 'C:\\Users\\Admin\\Desktop\\Research\\Datasets Used\\Face_Emotion\\validation'

#Data Augmentation 
train_datagen = ImageDataGenerator(
      rotation_range = 15,
    rescale = 1./255,
    shear_range = 0.1,
    zoom_range = 0.2,
    horizontal_flip = True,
    width_shift_range = 0.1,
    height_shift_range = 0.1)
 
validation_datagen = ImageDataGenerator(rescale=1./255)
 
train_generator = train_datagen.flow_from_directory(
        train_data_dir,
        color_mode = 'grayscale',
        target_size = (img_rows, img_cols),
        batch_size = batch_size,
        class_mode = 'categorical',
        shuffle = True)
 
validation_generator = validation_datagen.flow_from_directory(
        validation_data_dir,
        color_mode = 'grayscale',
        target_size = (img_rows, img_cols),
        batch_size = batch_size,
        class_mode = 'categorical',
        shuffle = True)
# Out:
# Using TensorFlow backend.
# Found 21975 images belonging to 4 classes.
# Found 2590 images belonging to 4 classes.

# %%
import tensorflow as tf
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
physical_devices = tf.config.experimental.list_physical_devices('GPU')
print("physical_devices-------------", len(physical_devices))
tf.config.experimental.set_memory_growth(physical_devices[0], True)
# Out:
# Num GPUs Available:  1
# physical_devices------------- 1

# %%
#Importing Keras packages
from __future__ import print_function
import os
import keras
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten, BatchNormalization
from keras.layers import Conv2D, MaxPooling2D, ZeroPadding2D
from keras.preprocessing.image import ImageDataGenerator
from keras.utils import np_utils
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from keras.models import load_model
from keras import optimizers
from tensorflow.keras.preprocessing import image
from keras.layers.advanced_activations import ELU, LeakyReLU, PReLU, ThresholdedReLU, Softmax, ReLU
from keras.regularizers import l2

# %%
#Initiating LiteNet for training
model = Sequential()

#1st Layer
model.add(Conv2D(64, (3, 3), padding = 'same', input_shape = input_shape, activation = 'elu', kernel_regularizer = l2(0.0005), 
                 kernel_initializer = "he_normal"))
model.add(BatchNormalization())

#2nd Layer
model.add(Conv2D(64, (3, 3), padding = 'same', input_shape = input_shape, activation = 'elu', kernel_regularizer = l2(0.0005), 
                 kernel_initializer = "he_normal"))
model.add(BatchNormalization())

#Pooling with Dropout
model.add(MaxPooling2D(pool_size = (2, 2)))
model.add(Dropout(0.10))

#3rd Layer
model.add(Conv2D(128, (3, 3), padding = 'same', input_shape = input_shape, activation = 'elu', kernel_regularizer = l2(0.0005), 
                 kernel_initializer = "he_normal"))
model.add(BatchNormalization())

#4th Layer
model.add(Conv2D(128, (3, 3), padding = 'same', input_shape = input_shape, activation = 'elu', kernel_regularizer = l2(0.0005), 
                 kernel_initializer = "he_normal"))
model.add(BatchNormalization())

#Pooling with Dropout
model.add(MaxPooling2D(pool_size = (2, 2)))
model.add(Dropout(0.10))

#5th Layer
model.add(Conv2D(256, (3, 3), padding = 'same', input_shape = input_shape, activation = 'elu', kernel_regularizer = l2(0.0005), 
                 kernel_initializer = "he_normal"))
model.add(BatchNormalization())

#6th Layer
model.add(Conv2D(256, (3, 3), padding = 'same', input_shape = input_shape, activation = 'elu', kernel_regularizer = l2(0.0005), 
                 kernel_initializer = "he_normal"))
model.add(BatchNormalization())

#Pooling with Dropout
model.add(MaxPooling2D(pool_size = (2, 2)))
model.add(Dropout(0.10))

#7th Layer
model.add(Conv2D(512, (3, 3), padding = 'same', input_shape = input_shape, activation = 'elu', kernel_regularizer = l2(0.0005), 
                 kernel_initializer = "he_normal"))
model.add(BatchNormalization())

#8th Layer
model.add(Conv2D(512, (3, 3), padding = 'same', input_shape = input_shape, activation = 'elu', kernel_regularizer = l2(0.0005), 
                 kernel_initializer = "he_normal"))
model.add(BatchNormalization())

#Pooling with Dropout
model.add(MaxPooling2D(pool_size = (2, 2)))
model.add(Dropout(0.15))

#9th Layer = 1st Fully Connected or Dense Layer
model.add(Flatten())
model.add(Dense(512, activation = 'elu', kernel_regularizer = l2(0.0005), 
                 kernel_initializer = "he_normal"))
model.add(BatchNormalization())
model.add(Dropout(0.15))

#10th Layer = 2nd Fully Connected or Dense Layer
model.add(Dense(512, activation = 'elu', kernel_regularizer = l2(0.0005), 
                 kernel_initializer = "he_normal"))
model.add(BatchNormalization())
model.add(Dropout(0.15))

#11th Layer = Final Layer
model.add(Dense(4, kernel_regularizer = l2(0.0005), 
                 kernel_initializer = "he_normal"))
model.add(Activation('softmax'))

print(model.summary())
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 48, 48, 64)        640
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 48, 48, 64)        256
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 48, 48, 64)        36928
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 48, 48, 64)        256
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 24, 24, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 24, 24, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 24, 24, 128)       73856
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 24, 24, 128)       512
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 24, 24, 128)       147584
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 24, 24, 128)       512
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 12, 12, 128)       0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 12, 12, 128)       0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 12, 12, 256)       295168
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 12, 12, 256)       1024
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 12, 12, 256)       590080
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 12, 12, 256)       1024
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 6, 6, 256)         0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 6, 6, 256)         0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 6, 6, 512)         1180160
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 6, 6, 512)         2048
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 6, 6, 512)         2359808
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 6, 6, 512)         2048
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 3, 3, 512)         0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 3, 3, 512)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 4608)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               2359808
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 512)               2048
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               262656
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 512)               2048
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 4)                 2052
# _________________________________________________________________
# activation_1 (Activation)    (None, 4)                 0
# =================================================================
# Total params: 7,320,516
# Trainable params: 7,314,628
# Non-trainable params: 5,888
# _________________________________________________________________
# None

# %%
from keras.optimizers import RMSprop, SGD, Adam
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau

                     
checkpoint = ModelCheckpoint("C:\\Users\\Admin\\Desktop\\Research\\Datasets Used\\Face_Emotion\\face_emotion_LiteNet_ELU.h5",
                             monitor = "val_loss",
                             mode = "min",
                             save_best_only = True,
                             verbose = 1)

earlystop = EarlyStopping(monitor = 'val_loss', 
                          min_delta = 0, 
                          patience = 20,
                          verbose = 1,
                          restore_best_weights = True)

reduce_lr = ReduceLROnPlateau(monitor = 'val_loss', factor = 0.25, patience = 3, verbose = 1, min_delta = 0.00001)

callbacks = [earlystop, checkpoint, reduce_lr]

model.compile(loss = 'categorical_crossentropy',
              optimizer = keras.optimizers.Adam(lr = 0.001), 
              metrics = ['accuracy'])

nb_train_samples = 21975
nb_validation_samples = 2590
epochs = 50

history = model.fit_generator(
    train_generator,
    steps_per_epoch = nb_train_samples // batch_size,
    epochs = epochs,
    callbacks = callbacks,
    validation_data = validation_generator,
    validation_steps = nb_validation_samples // batch_size)
# Out:
# Epoch 1/50
# 343/343 [==============================] - 23s 68ms/step - loss: 4.1312 - accuracy: 0.3560 - val_loss: 3.3867 - val_accuracy: 0.4172
#
# Epoch 00001: val_loss improved from inf to 3.38670, saving model to C:\Users\Admin\Desktop\Research\Datasets Used\Face_Emotion\face_emotion_LiteNet_ELU.h5
# Epoch 2/50
# 343/343 [==============================] - 19s 57ms/step - loss: 2.9012 - accuracy: 0.4567 - val_loss: 3.0734 - val_accuracy: 0.4256
#
# Epoch 00002: val_loss improved from 3.38670 to 3.07337, saving model to C:\Users\Admin\Desktop\Research\Datasets Used\Face_Emotion\face_emotion_LiteNet_ELU.h5
# Epoch 3/50
# 343/343 [==============================] - 19s 56ms/step - loss: 2.0720 - accuracy: 0.5177 - val_loss: 2.1139 - val_accuracy: 0.4276
#
# Epoch 00003: val_loss improved from 3.07337 to 2.11393, saving model to C:\Users\Admin\Desktop\Research\Datasets Used\Face_Emotion\face_emotion_LiteNet_ELU.h5
# Epoch 4/50
# 343/343 [==============================] - 19s 56ms/step - loss: 1.6291 - accuracy: 0.5611 - val_loss: 1.6507 - val_accuracy: 0.5174
#
# Epoch 00004: val_loss improved from 2.11393 to 1.65066, saving model to C:\Users\Admin\Desktop\Research\Datasets Used\Face_Emotion\face_emotion_LiteNet_ELU.h5
# Epoch 5/50
# 343/343 [==============================] - 19s 56ms/step - loss: 1.4126 - accuracy: 0.5761 - val_loss: 1.3852 - val_accuracy: 0.5629
#
# Epoch 00005: val_loss improved from 1.65066 to 1.38517, saving model to C:\Users\Admin\Desktop\Research\Datasets Used\Face_Emotion\face_emotion_LiteNet_ELU.h5
# Epoch 6/50
# 343/343 [==============================] - 19s 56ms/step - loss: 1.3098 - accuracy: 0.5910 - val_loss: 1.3618 - val_accuracy: 0.5281
#
# Epoch 00006: val_loss improved from 1.38517 to 1.36181, saving model to C:\Users\Admin\Desktop\Research\Datasets Used\Face_Emotion\face_emotion_LiteNet_ELU.h5
# Epoch 7/50
# 343/343 [==============================] - 19s 56ms/step - loss: 1.2543 - accuracy: 0.6051 - val_loss: 1.6302 - val_accuracy: 0.5249
#
# Epoch 00007: val_loss did not improve from 1.36181
# Epoch 8/50
# 343/343 [==============================] - 19s 56ms/step - loss: 1.2275 - accuracy: 0.6088 - val_loss: 1.6458 - val_accuracy: 0.4679
#
# Epoch 00008: val_loss did not improve from 1.36181
# Epoch 9/50
# 343/343 [==============================] - 19s 56ms/step - loss: 1.2247 - accuracy: 0.6091 - val_loss: 1.1680 - val_accuracy: 0.5744
#
# Epoch 00009: val_loss improved from 1.36181 to 1.16799, saving model to C:\Users\Admin\Desktop\Research\Datasets Used\Face_Emotion\face_emotion_LiteNet_ELU.h5
# Epoch 10/50
# 343/343 [==============================] - 19s 56ms/step - loss: 1.2148 - accuracy: 0.6163 - val_loss: 1.5194 - val_accuracy: 0.4873
#
# Epoch 00010: val_loss did not improve from 1.16799
# Epoch 11/50
# 343/343 [==============================] - 19s 56ms/step - loss: 1.2078 - accuracy: 0.6171 - val_loss: 1.3134 - val_accuracy: 0.5875
#
# Epoch 00011: val_loss did not improve from 1.16799
# Epoch 12/50
# 343/343 [==============================] - 19s 56ms/step - loss: 1.1952 - accuracy: 0.6222 - val_loss: 1.2569 - val_accuracy: 0.5032
#
# Epoch 00012: val_loss did not improve from 1.16799
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 13/50
# 343/343 [==============================] - 19s 56ms/step - loss: 1.0754 - accuracy: 0.6618 - val_loss: 1.2642 - val_accuracy: 0.6140
#
# Epoch 00013: val_loss did not improve from 1.16799
# Epoch 14/50
# 343/343 [==============================] - 19s 56ms/step - loss: 1.0143 - accuracy: 0.6771 - val_loss: 1.2568 - val_accuracy: 0.6041
#
# Epoch 00014: val_loss did not improve from 1.16799
# Epoch 15/50
# 343/343 [==============================] - 19s 56ms/step - loss: 0.9845 - accuracy: 0.6827 - val_loss: 1.4781 - val_accuracy: 0.6128
#
# Epoch 00015: val_loss did not improve from 1.16799
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Epoch 16/50
# 343/343 [==============================] - 19s 56ms/step - loss: 0.9274 - accuracy: 0.7015 - val_loss: 1.1768 - val_accuracy: 0.6394
#
# Epoch 00016: val_loss did not improve from 1.16799
# Epoch 17/50
# 343/343 [==============================] - 19s 56ms/step - loss: 0.9036 - accuracy: 0.7103 - val_loss: 1.1072 - val_accuracy: 0.6283
#
# Epoch 00017: val_loss improved from 1.16799 to 1.10722, saving model to C:\Users\Admin\Desktop\Research\Datasets Used\Face_Emotion\face_emotion_LiteNet_ELU.h5
# Epoch 18/50
# 343/343 [==============================] - 19s 56ms/step - loss: 0.8888 - accuracy: 0.7100 - val_loss: 1.5695 - val_accuracy: 0.6267
#
# Epoch 00018: val_loss did not improve from 1.10722
# Epoch 19/50
# 343/343 [==============================] - 19s 56ms/step - loss: 0.8746 - accuracy: 0.7132 - val_loss: 1.1934 - val_accuracy: 0.6405
#
# Epoch 00019: val_loss did not improve from 1.10722
# Epoch 20/50
# 343/343 [==============================] - 19s 56ms/step - loss: 0.8646 - accuracy: 0.7178 - val_loss: 0.9199 - val_accuracy: 0.6247
#
# Epoch 00020: val_loss improved from 1.10722 to 0.91991, saving model to C:\Users\Admin\Desktop\Research\Datasets Used\Face_Emotion\face_emotion_LiteNet_ELU.h5
# Epoch 21/50
# 343/343 [==============================] - 19s 56ms/step - loss: 0.8575 - accuracy: 0.7212 - val_loss: 1.3101 - val_accuracy: 0.6271
#
# Epoch 00021: val_loss did not improve from 0.91991
# Epoch 22/50
# 343/343 [==============================] - 19s 56ms/step - loss: 0.8507 - accuracy: 0.7196 - val_loss: 1.1159 - val_accuracy: 0.6453
#
# Epoch 00022: val_loss did not improve from 0.91991
# Epoch 23/50
# 343/343 [==============================] - 19s 56ms/step - loss: 0.8422 - accuracy: 0.7244 - val_loss: 1.4135 - val_accuracy: 0.6192
#
# Epoch 00023: val_loss did not improve from 0.91991
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# Epoch 24/50
# 343/343 [==============================] - 19s 56ms/step - loss: 0.8196 - accuracy: 0.7320 - val_loss: 1.2592 - val_accuracy: 0.6306
#
# Epoch 00024: val_loss did not improve from 0.91991
# Epoch 25/50
# 343/343 [==============================] - 19s 56ms/step - loss: 0.8109 - accuracy: 0.7353 - val_loss: 1.5034 - val_accuracy: 0.6338
#
# Epoch 00025: val_loss did not improve from 0.91991
# Epoch 26/50
# 343/343 [==============================] - 19s 56ms/step - loss: 0.8061 - accuracy: 0.7349 - val_loss: 1.1527 - val_accuracy: 0.6437
#
# Epoch 00026: val_loss did not improve from 0.91991
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# Epoch 27/50
# 343/343 [==============================] - 19s 56ms/step - loss: 0.8013 - accuracy: 0.7385 - val_loss: 1.1120 - val_accuracy: 0.6322
#
# Epoch 00027: val_loss did not improve from 0.91991
# Epoch 28/50
# 343/343 [==============================] - 19s 56ms/step - loss: 0.7993 - accuracy: 0.7396 - val_loss: 1.2848 - val_accuracy: 0.6382
#
# Epoch 00028: val_loss did not improve from 0.91991
# Epoch 29/50
# 343/343 [==============================] - 19s 56ms/step - loss: 0.7903 - accuracy: 0.7439 - val_loss: 1.4555 - val_accuracy: 0.6362
#
# Epoch 00029: val_loss did not improve from 0.91991
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 9.765625463842298e-07.
# Epoch 30/50
# 343/343 [==============================] - 19s 56ms/step - loss: 0.7960 - accuracy: 0.7416 - val_loss: 1.3331 - val_accuracy: 0.6469
#
# Epoch 00030: val_loss did not improve from 0.91991
# Epoch 31/50
# 343/343 [==============================] - 19s 56ms/step - loss: 0.7964 - accuracy: 0.7409 - val_loss: 1.3331 - val_accuracy: 0.6378
#
# Epoch 00031: val_loss did not improve from 0.91991
# Epoch 32/50
# 343/343 [==============================] - 19s 56ms/step - loss: 0.7954 - accuracy: 0.7433 - val_loss: 1.2093 - val_accuracy: 0.6417
#
# Epoch 00032: val_loss did not improve from 0.91991
#
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 2.4414063659605745e-07.
# Epoch 33/50
# 343/343 [==============================] - 19s 56ms/step - loss: 0.7951 - accuracy: 0.7408 - val_loss: 1.8463 - val_accuracy: 0.6374
#
# Epoch 00033: val_loss did not improve from 0.91991
# Epoch 34/50
# 343/343 [==============================] - 19s 56ms/step - loss: 0.7895 - accuracy: 0.7449 - val_loss: 1.2015 - val_accuracy: 0.6401
#
# Epoch 00034: val_loss did not improve from 0.91991
# Epoch 35/50
# 343/343 [==============================] - 19s 56ms/step - loss: 0.7938 - accuracy: 0.7448 - val_loss: 1.0968 - val_accuracy: 0.6413
#
# Epoch 00035: val_loss did not improve from 0.91991
#
# Epoch 00035: ReduceLROnPlateau reducing learning rate to 6.103515914901436e-08.
# Epoch 36/50
# 343/343 [==============================] - 19s 56ms/step - loss: 0.7911 - accuracy: 0.7456 - val_loss: 1.2534 - val_accuracy: 0.6382
#
# Epoch 00036: val_loss did not improve from 0.91991
# Epoch 37/50
# 343/343 [==============================] - 19s 56ms/step - loss: 0.7919 - accuracy: 0.7430 - val_loss: 1.4910 - val_accuracy: 0.6437
#
# Epoch 00037: val_loss did not improve from 0.91991
# Epoch 38/50
# 343/343 [==============================] - 19s 56ms/step - loss: 0.7929 - accuracy: 0.7433 - val_loss: 1.2216 - val_accuracy: 0.6378
#
# Epoch 00038: val_loss did not improve from 0.91991
#
# Epoch 00038: ReduceLROnPlateau reducing learning rate to 1.525878978725359e-08.
# Epoch 39/50
# 343/343 [==============================] - 19s 56ms/step - loss: 0.7899 - accuracy: 0.7448 - val_loss: 1.1252 - val_accuracy: 0.6449
#
# Epoch 00039: val_loss did not improve from 0.91991
# Epoch 40/50
# 343/343 [==============================] - 19s 56ms/step - loss: 0.7864 - accuracy: 0.7475 - val_loss: 1.5092 - val_accuracy: 0.6346
# Restoring model weights from the end of the best epoch
#
# Epoch 00040: val_loss did not improve from 0.91991
# Epoch 00040: early stopping

# %%
#Evaluating training and test error
import matplotlib.pyplot as plt
history_dict = history.history
loss_values = history_dict['loss']
val_loss_values = history_dict['val_loss']
epochs = range(1, len(loss_values) + 1)
line1 = plt.plot(epochs, val_loss_values, label = 'Validation/Test Loss')
line2 = plt.plot(epochs, loss_values, label = 'Training Loss')
plt.setp(line1, linewidth = 2.0, marker = '+', markersize = 10.0)
plt.setp(line2, linewidth = 2.0, marker = '4', markersize = 10.0)
plt.xlabel('Epochs') 
plt.ylabel('Loss')
plt.grid(True)
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import sklearn
from sklearn.metrics import classification_report, confusion_matrix
import numpy as np

nb_train_samples = 21975
nb_validation_samples = 2590

validation_generator = validation_datagen.flow_from_directory(
        validation_data_dir,
        color_mode = 'grayscale',
        target_size = (img_rows, img_cols),
        batch_size = batch_size,
        class_mode = 'categorical',
        shuffle = False)

class_labels = validation_generator.class_indices
class_labels = {v: k for k, v in class_labels.items()}
classes = list(class_labels.values())

#Confusion Matrix and Classification Report
Y_pred = model.predict_generator(validation_generator, nb_validation_samples // batch_size+1)
y_pred = np.argmax(Y_pred, axis = 1)

print('Confusion Matrix')
print(confusion_matrix(validation_generator.classes, y_pred))
print('Classification Report')
target_names = list(class_labels.values())
print(classification_report(validation_generator.classes, y_pred, target_names = target_names))

plt.figure(figsize = (8,8))
cnf_matrix = confusion_matrix(validation_generator.classes, y_pred)

plt.imshow(cnf_matrix, interpolation = 'nearest')

plt.colorbar()
tick_marks = np.arange(len(classes))
_ = plt.xticks(tick_marks, classes, rotation = 90)
_ = plt.yticks(tick_marks, classes)
# Out:
# Found 2590 images belonging to 4 classes.
# Confusion Matrix
# [[361   7  75  48]
#  [ 35 758  70  16]
#  [169 151 188 118]
#  [ 78  22 183 311]]
# Classification Report
#               precision    recall  f1-score   support
#
#        Angry       0.56      0.74      0.64       491
#        Happy       0.81      0.86      0.83       879
#      Neutral       0.36      0.30      0.33       626
#          Sad       0.63      0.52      0.57       594
#
#     accuracy                           0.62      2590
#    macro avg       0.59      0.61      0.59      2590
# weighted avg       0.61      0.62      0.61      2590

# %%
from keras.models import load_model

classifier = load_model('C:\\Users\\Admin\\Desktop\\Research\\Datasets Used\\Face_Emotion\\face_emotion_LiteNet_ELU.h5')

# %%
validation_generator = validation_datagen.flow_from_directory(
        validation_data_dir,
        color_mode = 'grayscale',
        target_size = (img_rows, img_cols),
        batch_size = batch_size,
        class_mode = 'categorical',
        shuffle = False)

class_labels = validation_generator.class_indices
class_labels = {v: k for k, v in class_labels.items()}
classes = list(class_labels.values())
print(class_labels)
# Out:
# Found 2590 images belonging to 4 classes.
# {0: 'Angry', 1: 'Happy', 2: 'Neutral', 3: 'Sad'}

# %%
from keras.models import load_model
from keras.optimizers import RMSprop, SGD, Adam
from keras.preprocessing import image
import numpy as np
import os
import cv2
import numpy as np
from os import listdir
from os.path import isfile, join
import re

def draw_test(name, pred, im, true_label):
    BLACK = [0,0,0]
    expanded_image = cv2.copyMakeBorder(im, 160, 0, 0, 300 ,cv2.BORDER_CONSTANT,value = BLACK)
    cv2.putText(expanded_image, "predited - "+ pred, (20, 60) , cv2.FONT_HERSHEY_SIMPLEX,1, (0,0,255), 2)
    cv2.putText(expanded_image, "true - "+ true_label, (20, 120) , cv2.FONT_HERSHEY_SIMPLEX,1, (0,255,0), 2)
    cv2.imshow(name, expanded_image)


def getRandomImage(path, img_width, img_height):
    """function loads a random images from a random folder in our test path """
    folders = list(filter(lambda x: os.path.isdir(os.path.join(path, x)), os.listdir(path)))
    random_directory = np.random.randint(0,len(folders))
    path_class = folders[random_directory]
    file_path = path + path_class
    file_names = [f for f in listdir(file_path) if isfile(join(file_path, f))]
    random_file_index = np.random.randint(0,len(file_names))
    image_name = file_names[random_file_index]
    final_path = file_path + "/" + image_name
    return image.load_img(final_path, target_size = (img_width, img_height),grayscale = True), final_path, path_class

img_width, img_height = 48, 48

model.compile(loss = 'categorical_crossentropy',
              optimizer = keras.optimizers.Adam(lr = 0.001),
              metrics = ['accuracy'])

files = []
predictions = []
true_labels = []

#Predicting images
for i in range(0, 10):
    path = 'C:\\Users\\Admin\\Desktop\\Research\\Datasets Used\\Face_Emotion\\validation\\' 
    img, final_path, true_label = getRandomImage(path, img_width, img_height)
    files.append(final_path)
    true_labels.append(true_label)
    x = image.img_to_array(img)
    x = x * 1./255
    x = np.expand_dims(x, axis = 0)
    images = np.vstack([x])
    classes = model.predict_classes(images, batch_size = 10)
    predictions.append(classes)
    
for i in range(0, len(files)):
    image = cv2.imread((files[i]))
    image = cv2.resize(image, None, fx = 3, fy = 3, interpolation = cv2.INTER_CUBIC)
    draw_test("Prediction", class_labels[predictions[i][0]], image, true_labels[i])
    cv2.waitKey(0)

cv2.destroyAllWindows()
# Out:
# C:\Users\Admin\Anaconda3\lib\site-packages\keras_preprocessing\image\utils.py:107: UserWarning: grayscale is deprecated. Please use color_mode = "grayscale"
#   warnings.warn('grayscale is deprecated. Please use '

# %%
from keras.models import load_model
from keras.preprocessing import image
import numpy as np
import os
import cv2
import numpy as np
from os import listdir
from os.path import isfile, join
from keras.preprocessing.image import img_to_array

face_classifier = cv2.CascadeClassifier('C:\\Users\\Admin\\Desktop\\Research\\Datasets Used\\Face_Emotion\\Haarcascades\\haarcascade_frontalface_default.xml')

def face_detector(img):
    #Convert image to greyscale
    gray = cv2.cvtColor(img.copy(),cv2.COLOR_BGR2GRAY)
    faces = face_classifier.detectMultiScale(gray, 1.3, 5)
    if faces is ():
        return (0,0,0,0), np.zeros((48,48), np.uint8), img
    
    allfaces = []   
    rects = []
    for (x,y,w,h) in faces:
        cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
        roi_gray = gray[y:y+h, x:x+w]
        roi_gray = cv2.resize(roi_gray, (48, 48), interpolation = cv2.INTER_AREA)
        allfaces.append(roi_gray)
        rects.append((x,w,y,h))
    return rects, allfaces, img

img = cv2.imread("C:\\Users\\Admin\\Desktop\\Research\\Datasets Used\\Face_Emotion\\Working Images\\2016-08-11 01.56.05 1-cropped.jpg")
rects, faces, image = face_detector(img)

i = 0
for face in faces:
    roi = face.astype("float") / 255.0
    roi = img_to_array(roi)
    roi = np.expand_dims(roi, axis=0)

    #Make a prediction on the ROI, then lookup the class
    preds = classifier.predict(roi)[0]
    label = class_labels[preds.argmax()]   

    label_position = (rects[i][0] + int((rects[i][1]/2)), abs(rects[i][2] - 10))
    i =+ 1
    cv2.putText(image, label, label_position , cv2.FONT_HERSHEY_SIMPLEX,1, (0,255,0), 2)
    
cv2.imshow("Emotion Detector", image)
cv2.waitKey(0)

cv2.destroyAllWindows()

# %%
cap.release()
cv2.destroyAllWindows()
